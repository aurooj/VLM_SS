# %%
import os
import pandas as pd

# %%
df = pd.read_csv("/mnt/PURENFS/SalkowskiPreprocessedBreast/code/MedCLIP/local_data/uwmadison-val-meta.csv", index_col=0)

# %%
df.to_dict('records')
# Out:
# [{'img_id': 'UWMF23147904_151976_151977',
#   'imgpath': '/mnt/PURENFS/SalkowskiPreprocessedBreast/processed_for_albef/UWMF23147904_151976_151977.png',
#   'AccessionNumber': 'UWMF23147904',
#   'group': "['heterogeneously dense']",
#   'mass': 0.0,
#   'features': 0.0,
#   'calcification': 0.0,
#   'asymmetry': 0.0,
#   'surgical change': 0.0,
#   'distortion': 0.0,
#   'fatty': 0.0,
#   'scattered fibroglandular density': 0.0,
#   'heterogeneously dense': 0.0,
#   'extreme dense': 0.0,
#   'lesion': 0.0,
#   'implant': 0.0,
#   'No Finding': 1.0,
# ...
