# %%
# Authors: 
#     Author: Amara Tariq
#     Author: Aisha Urooj
# Institute: Mayo Clinic, AZ

# %%
import pandas as pd
import numpy as np
import os
import json
import pickle as pkl
import re
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from skimage import io
from tqdm.auto import tqdm
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from string import punctuation
# Out:
# [nltk_data] Downloading package punkt to /home/ixb004/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def load_json(file_path):
    with open(file_path, "r") as f:
        return json.load(f)


def save_json(data, file_path):
    with open(file_path, "w") as f:
        json.dump(data, f)

# %%
data_path = "data/sample_data.json"

# %%
df = pd.read_json(data_path)
df
# Out:
#       Accession Number                                            caption
# 0         IEIWXXMIASHB  The breasts have scattered areas of fibrogland...
# 1         HQBWALCOXMIQ  The breasts have scattered areas of fibrogland...
# 2         SVSQKIZBKPTB  \nThere are scattered fibroglandular elements ...
# 3         SYZGIPYGTPMU  \nThe tissue of both breasts is heterogeneousl...
# 4         XFGVIXZRKMQT  \nThere are scattered fibroglandular elements ...
# ...                ...                                                ...
# 21073     BGOKNITYACYV  The breasts are heterogeneously dense, which m...
# 21074     XFHUSVEZFLNJ  The breasts are heterogeneously dense, which m...
# 21075     GWCZYYNCJMUY  The breasts have scattered areas of fibrogland...
# 21076     ROCGIOPQROJN  \nThe breasts are heterogeneously dense, which...
# 21077     VAZAWPZRBYQZ  \nThe breast is heterogeneously dense, which m...
#
# [21000 rows x 2 columns]

# %%
def clean_txt(txt):
    txt = txt.encode("ascii", errors="ignore").decode()
    txt = txt.lower()
    txt = txt.replace('\n', ' ')
    txt = txt.replace('\r', ' ')
    txt = txt.replace('\t', ' ')
    re1 = '(\\()'  # Any Single Character 1
    re2 = '.*?'  # Non-greedy match on filler
    re3 = '(\\))'  # Any Single Character 2

    rg = re.compile(re1 + re2 + re3, re.IGNORECASE | re.DOTALL)
    out = re.sub(rg, ' ', txt)
    return out
    

def extract_findings(txt):
    dct = report_split_old(txt)
    s = 'findings: '
    if len(dct[s])>1:
        txt = re.sub('\s+', ' ', dct[s])
        return txt

# %%
#clean findings
df = df.assign(caption = df.caption.apply(clean_txt))

# %%
def extract_density(txt):
    dct = report_split_old(txt)
    s = 'density: '
    if len(dct[s])>1:
        txt = re.sub('\s+', ' ', dct[s])
        return txt


#function modified from Amara's script
def extract_density_category(txt):
    if type(txt) is str:
        sents = sent_tokenize(txt)
        
        for s in sents:
            if "scattered" in s and "fibroglandular" in s and 'no ' not in s:
                return 'scattered fibroglandular densities'
            elif "heterogeneous" in s and "dens" in s and 'no ' not in s:
                return 'heterogeneously dense'
            elif "fat" in s and ("entire" in s or "predominantly" in s) and 'no ' not in s:
                return "fatty"
            elif "extreme" in s and "dens" in s and 'no ' not in s:
                return "extremely dense"

# %%
df = df.assign(DENSITY_CATEGORY = df.caption.apply(extract_density_category))
df['DENSITY_CATEGORY'].value_counts()
# Out:
# DENSITY_CATEGORY
# scattered fibroglandular densities    10722
# heterogeneously dense                  7989
# fatty                                  1534
# extremely dense                         634
# Name: count, dtype: int64

# %%
"""

Calcifications        

Typically benign 

Skin 
Vascular 
Coarse or “popcorn-like” 
Large rod-like 
Round 
Rim 
Dystrophic 
Milk of calcium 
Suture 

Suspicious  morphology 

Amorphous 
Coarse heterogeneous 
Fine pleomorphic 
Fine linear or fine-linear branching 

Distribution

Diffuse 
Regional 
Grouped 
Linear 
Segmental
"""
def extract_calcification(txt):
    '''
    txt is extracted findings // already lower case and cleaned
    '''
    if type(txt) is str:
        chars_benign = ['skin', 'vascular', 'caorse', 'popcorn', 'large', 'rod-like', 'round', 'rim', 'dystrophic', 'milk of calcium', 'suture', 'benign']
        chars_suspicious = ['amorphous', 'coarse heterogenous', 'fine pleomorphic', 'fine-linear']
        chars_distribution = ['diffuse', 'regional', 'grouped', 'linear', 'segmental']
        
        chars = chars_benign + chars_suspicious + chars_distribution

        sents = sent_tokenize(txt)

        out = []
        for s in sents:
            if 'calcification' in s and 'no ' not in s: # mass without negation

                chars_sel = [ch for ch in chars if ch in s]
                
#                 group = ', '.join(chars_sel).strip()
                if len(chars_sel)>0:
                    out.extend(chars_sel)
            
        out = list(set(sorted(out)))
        out = ", ".join(out)
        
        out = out.replace('benign', 'benign calcification')
        if out != "":
            return out
            
            
        
df = df.assign(CALCIFICATION = df.caption.apply(extract_calcification))


df['CALCIFICATION'].value_counts()
# Out:
# CALCIFICATION
# benign calcification                       1330
# grouped                                      47
# vascular, benign calcification               14
# dystrophic, benign calcification              6
# vascular                                      5
# skin, benign calcification                    5
# benign calcification, round                   3
# amorphous, grouped                            3
# grouped, benign calcification                 3
# linear                                        3
# diffuse, benign calcification                 3
# diffuse                                       3
# round                                         3
# dystrophic                                    2
# milk of calcium, benign calcification         1
# grouped, round                                1
# regional                                      1
# popcorn, regional                             1
# segmental                                     1
# skin                                          1
# fine-linear, linear                           1
# grouped, benign calcification, round          1
# large, dystrophic, benign calcification       1
# linear, round                                 1
# rim                                           1
# linear, fine-linear, grouped                  1
# diffuse, vascular, benign calcification       1
# skin, vascular                                1
# rim, benign calcification                     1
# Name: count, dtype: int64

# %%
"""
Architectural distortion 

Asymmetries

Asymmetry 
Global asymmetry 
Focal asymmetry 
Developing asymmetry 

Intramammary lymph node 

Skin lesion 

Solitary dilated duct 

Associated  features:
Skin retraction 
Nipple retraction 
Skin thickening 
Trabecular thickening 
Axillary adenopathy 
Architectural distortion 
Calcifications 


"""
def extract_asymmetry(txt):
    '''
    txt is extracted findings // already lower case and cleaned
    '''
    if type(txt) is str:
        chars = ['global', 'focal', 'developing', 'questioned']
        sents = sent_tokenize(txt)
        out = []
        for s in sents:
            
            if 'asymmetr' in s and 'no ' not in s: # mass without negation
                out.append('asymmetry')
                chars = [ch for ch in chars if ch in s]
                if len(chars)>0:
                    out.extend(chars)
#                     return out+' '.join(chars)
        if len(out)>0:
            out = list(set(sorted(out)))
            out = " ".join(out)
            return out
            
df = df.assign(ASYMMETRY = df.caption.apply(extract_asymmetry))
df['ASYMMETRY'].value_counts()
# Out:
# ASYMMETRY
# asymmetry               175
# asymmetry focal         173
# asymmetry developing      3
# asymmetry global          2
# Name: count, dtype: int64

# %%
def extract_add_features(txt):
    '''
    txt is extracted findings // already lower case and cleaned
    '''
    if type(txt) is str:
        chars = ['skin lesion', 'solitary dilated duct', 'skin retraction', 
                 'nipple retraction', 'skin thickening', 'trabecular thickening', 'axillary adenopathy', 
                 'architectural distortion', 'intramammary node', 'lymph node']
        sents = sent_tokenize(txt)
        out = []
        for s in sents:
            for ch in chars:
                if ch in s and 'no ' not in s and ch not in out:
                    out.append(ch)
#                     if out!='':
#                         out = out+', '+ch
#                     else:
#                         out = ch
        
        if len(out)>0:
            return ", ".join(list(set(sorted(out))))
df = df.assign(FEATURES = df.caption.apply(extract_add_features))
df['FEATURES'].value_counts()
# Out:
# FEATURES
# lymph node                                   131
# architectural distortion                      80
# skin thickening                               17
# skin lesion                                    9
# trabecular thickening                          5
# intramammary node                              2
# skin thickening, lymph node                    1
# trabecular thickening, skin thickening         1
# skin thickening, architectural distortion      1
# trabecular thickening, lymph node              1
# Name: count, dtype: int64

# %%
import string
def extract_mass(txt):
    '''
    txt is extracted findings // already lower case and cleaned
    '''
    if type(txt) is str:
        chars = ['oval', 'round','irregular', 'circumscribed', 'obscured', 'microlobulated', 'indistinct', 'nodul', 'node',
             'nodule','nodular', 'spiculated', 'high density', 'equal density', 'low density', 'fat-containing', 'possible']
        sents = sent_tokenize(txt)
        out = []
        flag=False
        for s in sents:    
            if 'mass' in s and 'no ' not in s and 'obscure small masses' not in s: # mass without negation
                flag=True
                chars_sel = [ch for ch in chars if ch in s and ch not in out]
                if len(chars_sel)>0:
                    out.extend(chars_sel)
#                     out =  out+' '+', '.join(chars_sel)
        if len(out)>0:
            out = list(set(sorted(out)))
            out = ", ".join(out)
        elif flag:
            out = 'mass'
        if flag:
            return out
df = df.assign(MASS = df.caption.apply(extract_mass))
df['MASS'].value_counts()
# Out:
# MASS
# mass                                    917
# obscured, oval, circumscribed, round    245
# oval                                     37
# round                                     8
# oval, circumscribed, equal density        6
# node                                      6
# circumscribed                             5
# obscured, oval                            3
# obscured, oval, equal density             3
# circumscribed, round                      3
# irregular                                 3
# obscured, round                           2
# oval, round                               2
# oval, circumscribed, round                2
# oval, obscured, high density              2
# oval, circumscribed                       2
# obscured                                  2
# indistinct, equal density, round          1
# low density                               1
# spiculated, round                         1
# oval, equal density                       1
# indistinct, irregular                     1
# spiculated                                1
# high density, circumscribed, round        1
# obscured, circumscribed, node             1
# possible, circumscribed                   1
# irregular, spiculated                     1
# equal density                             1
# indistinct                                1
# oval, node                                1
# circumscribed, equal density              1
# round, oval, circumscribed, node          1
# fat-containing                            1
# oval, fat-containing, circumscribed       1
# oval, fat-containing, microlobulated      1
# indistinct, irregular, equal density      1
# Name: count, dtype: int64

# %%
df
# Out:
#       Accession Number                                            caption  \
# 0         IEIWXXMIASHB  the breasts have scattered areas of fibrogland...
# 1         HQBWALCOXMIQ  the breasts have scattered areas of fibrogland...
# 2         SVSQKIZBKPTB   there are scattered fibroglandular elements i...
# 3         SYZGIPYGTPMU   the tissue of both breasts is heterogeneously...
# 4         XFGVIXZRKMQT   there are scattered fibroglandular elements i...
# ...                ...                                                ...
# 21073     BGOKNITYACYV  the breasts are heterogeneously dense, which m...
# 21074     XFHUSVEZFLNJ  the breasts are heterogeneously dense, which m...
# 21075     GWCZYYNCJMUY  the breasts have scattered areas of fibrogland...
# 21076     ROCGIOPQROJN   the breasts are heterogeneously dense, which ...
# 21077     VAZAWPZRBYQZ   the breast is heterogeneously dense, which ma...
#
#                          DENSITY_CATEGORY         CALCIFICATION  \
# 0      scattered fibroglandular densities                  None
# 1      scattered fibroglandular densities                  None
# 2      scattered fibroglandular densities                  None
# 3                   heterogeneously dense  benign calcification
# 4      scattered fibroglandular densities  benign calcification
# ...                                   ...                   ...
# 21073               heterogeneously dense                  None
# 21074               heterogeneously dense                  None
# 21075  scattered fibroglandular densities                  None
# 21076               heterogeneously dense                  None
# 21077               heterogeneously dense  benign calcification
#
#              ASYMMETRY FEATURES  MASS
# 0            asymmetry     None  None
# 1                 None     None  None
# 2                 None     None  None
# 3                 None     None  None
# 4                 None     None  None
# ...                ...      ...   ...
# 21073  asymmetry focal     None  None
# 21074             None     None  None
# 21075             None     None  None
# 21076             None     None  None
# 21077             None     None  None
#
# [21000 rows x 7 columns]

# %%
df.iloc[20999]['caption']
# Out:
# ' the breast is heterogeneously dense, which may obscure small masses.   there are typically benign calcifications in the right breast.  there are no significant masses, calcifications, or other findings.'

# %%
#retrieve reports with mass in findings
df_mass = df[df['MASS']=='mass']
df_mass.iloc[100]['caption']
# Out:
# 'the breasts have scattered areas of fibroglandular density.  there is a stable benign mass in the left breast.   there are no significant masses, calcifications, or other findings'

# %%
df = df.reset_index()  # make sure indexes pair with number of rows

# %%
def extract_surgical_changes(txt):
    '''
    txt is extracted findings // already lower case and cleaned
    '''
    if type(txt) is str:
        chars = ['lumpectomy', 'reduction', 'implant', 'biopsy', 'clip']
        sents = sent_tokenize(txt)
        out = []
        for s in sents:

            if 'no ' not in s: # mass without negation
#                 print(s)
                chars_sel = [ch for ch in chars if ch in s and ch not in out]
                if len(chars_sel)>0:
                    out.extend(chars_sel)
                
        if len(out)>0:
            out = list(set(sorted(out)))
            return ' '.join(out)
        elif  'post operative finding' in txt:
            return 'post operative finding'
            
df = df.assign(SURGICAL_CHANGES = df.caption.apply(extract_surgical_changes))
df['SURGICAL_CHANGES'].value_counts()
# Out:
# SURGICAL_CHANGES
# biopsy clip                                 1758
# lumpectomy                                  1564
# biopsy                                      1335
# implant                                      596
# reduction                                    542
# lumpectomy biopsy clip                       422
# lumpectomy biopsy                            150
# lumpectomy reduction                          92
# reduction biopsy clip                         77
# implant biopsy clip                           39
# implant lumpectomy                            36
# reduction biopsy                              31
# implant biopsy                                29
# lumpectomy reduction biopsy clip              25
# implant reduction                             19
# lumpectomy clip                               15
# clip                                          14
# post operative finding                         6
# implant biopsy clip lumpectomy                 6
# implant clip                                   3
# implant biopsy lumpectomy                      3
# reduction clip                                 3
# implant reduction biopsy clip                  1
# implant reduction lumpectomy biopsy clip       1
# implant reduction lumpectomy                   1
# Name: count, dtype: int64

# %%
#following code is to rename similar concepts to standardize the terms 
df.loc[df['SURGICAL_CHANGES']  == 'clip lumpectomy', 'SURGICAL_CHANGES'] = 'biopsy clip lumpectomy'
df['SURGICAL_CHANGES'].value_counts()
# Out:
# SURGICAL_CHANGES
# biopsy clip                                 1758
# lumpectomy                                  1564
# biopsy                                      1335
# implant                                      596
# reduction                                    542
# lumpectomy biopsy clip                       422
# lumpectomy biopsy                            150
# lumpectomy reduction                          92
# reduction biopsy clip                         77
# implant biopsy clip                           39
# implant lumpectomy                            36
# reduction biopsy                              31
# implant biopsy                                29
# lumpectomy reduction biopsy clip              25
# implant reduction                             19
# lumpectomy clip                               15
# clip                                          14
# post operative finding                         6
# implant biopsy clip lumpectomy                 6
# implant clip                                   3
# implant biopsy lumpectomy                      3
# reduction clip                                 3
# implant reduction biopsy clip                  1
# implant reduction lumpectomy biopsy clip       1
# implant reduction lumpectomy                   1
# Name: count, dtype: int64

# %%
#following code is to rename similar concepts to standardize the terms 
df.loc[df['SURGICAL_CHANGES']  == 'biopsy lumpectomy', 'SURGICAL_CHANGES'] = 'biopsy clip lumpectomy'
df['SURGICAL_CHANGES'].value_counts()
# Out:
# SURGICAL_CHANGES
# biopsy clip                                 1758
# lumpectomy                                  1564
# biopsy                                      1335
# implant                                      596
# reduction                                    542
# lumpectomy biopsy clip                       422
# lumpectomy biopsy                            150
# lumpectomy reduction                          92
# reduction biopsy clip                         77
# implant biopsy clip                           39
# implant lumpectomy                            36
# reduction biopsy                              31
# implant biopsy                                29
# lumpectomy reduction biopsy clip              25
# implant reduction                             19
# lumpectomy clip                               15
# clip                                          14
# post operative finding                         6
# implant biopsy clip lumpectomy                 6
# implant clip                                   3
# implant biopsy lumpectomy                      3
# reduction clip                                 3
# implant reduction biopsy clip                  1
# implant reduction lumpectomy biopsy clip       1
# implant reduction lumpectomy                   1
# Name: count, dtype: int64

# %%
#following code is to rename similar concepts to standardize the terms 
df.loc[df['SURGICAL_CHANGES']  == 'biopsy implant', 'SURGICAL_CHANGES'] = 'biopsy clip implant'
df.loc[df['SURGICAL_CHANGES']  == 'clip implant', 'SURGICAL_CHANGES'] = 'biopsy clip implant'
df['SURGICAL_CHANGES'].value_counts()
# Out:
# SURGICAL_CHANGES
# biopsy clip                                 1758
# lumpectomy                                  1564
# biopsy                                      1335
# implant                                      596
# reduction                                    542
# lumpectomy biopsy clip                       422
# lumpectomy biopsy                            150
# lumpectomy reduction                          92
# reduction biopsy clip                         77
# implant biopsy clip                           39
# implant lumpectomy                            36
# reduction biopsy                              31
# implant biopsy                                29
# lumpectomy reduction biopsy clip              25
# implant reduction                             19
# lumpectomy clip                               15
# clip                                          14
# post operative finding                         6
# implant biopsy clip lumpectomy                 6
# implant clip                                   3
# implant biopsy lumpectomy                      3
# reduction clip                                 3
# implant reduction biopsy clip                  1
# implant reduction lumpectomy biopsy clip       1
# implant reduction lumpectomy                   1
# Name: count, dtype: int64

# %%
#following code is to rename similar concepts to standardize the terms 
df.loc[df['SURGICAL_CHANGES']  == 'biopsy', 'SURGICAL_CHANGES'] = 'biopsy clip'
df.loc[df['SURGICAL_CHANGES']  == 'clip', 'SURGICAL_CHANGES'] = 'biopsy clip'
df['SURGICAL_CHANGES'].value_counts()
# Out:
# SURGICAL_CHANGES
# biopsy clip                                 3107
# lumpectomy                                  1564
# implant                                      596
# reduction                                    542
# lumpectomy biopsy clip                       422
# lumpectomy biopsy                            150
# lumpectomy reduction                          92
# reduction biopsy clip                         77
# implant biopsy clip                           39
# implant lumpectomy                            36
# reduction biopsy                              31
# implant biopsy                                29
# lumpectomy reduction biopsy clip              25
# implant reduction                             19
# lumpectomy clip                               15
# post operative finding                         6
# implant biopsy clip lumpectomy                 6
# implant clip                                   3
# implant biopsy lumpectomy                      3
# reduction clip                                 3
# implant reduction biopsy clip                  1
# implant reduction lumpectomy biopsy clip       1
# implant reduction lumpectomy                   1
# Name: count, dtype: int64

# %%
#create groups by merging extracted image descriptors from text reports
groups = []
for index, row in tqdm(df.iterrows()):

    group = [row['DENSITY_CATEGORY'], row['MASS'], row['CALCIFICATION'], row['ASYMMETRY'], 
             row['FEATURES'],row['SURGICAL_CHANGES']]
    group = [g.strip().strip(punctuation) for g in group if g not in ["", " ", ",", ", ", None] ]
    groups.append(tuple(set(sorted(group))))
    
df = df.assign(GROUP = groups)
# Out:
# 21000it [00:03, 6052.23it/s]

# %%
#unique number of groups
print(len(set(groups)))
# Out:
# 414

# %%
#remove samples with empty group, Note: should have cleaned it before starting grouping, 
# but in case if any empty groups appear, remove them
df = df[df["GROUP"]!=()]
len(df)
# Out:
# 20886

# %%
from collections import Counter
Counter(groups).most_common()
# Out:
# [(('scattered fibroglandular densities',), 6174),
#  (('heterogeneously dense',), 4496),
#  (('biopsy clip', 'scattered fibroglandular densities'), 1216),
#  (('heterogeneously dense', 'biopsy clip'), 1054),
#  (('fatty',), 1030),
#  (('lumpectomy', 'scattered fibroglandular densities'), 886),
#  (('lumpectomy', 'heterogeneously dense'), 412),
#  (('benign calcification', 'heterogeneously dense'), 362),
#  (('extremely dense',), 328),
#  (('reduction', 'scattered fibroglandular densities'), 316),
#  (('benign calcification', 'scattered fibroglandular densities'), 286),
#  (('mass', 'scattered fibroglandular densities'), 278),
#  (('implant', 'scattered fibroglandular densities'), 257),
#  (('implant', 'heterogeneously dense'), 232),
#  (('mass', 'heterogeneously dense'), 215),
#  (('lumpectomy biopsy clip', 'scattered fibroglandular densities'), 210),
#  (('heterogeneously dense', 'lumpectomy biopsy clip'), 144),
#  (('fatty', 'biopsy clip'), 143),
#  (('heterogeneously dense', 'benign calcification', 'biopsy clip'), 122),
#  (('biopsy clip', 'extremely dense'), 116),
#  ((), 114),
#  (('mass', 'heterogeneously dense', 'biopsy clip'), 106),
#  (('reduction', 'heterogeneously dense'), 93),
#  (('benign calcification',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   88),
#  (('mass', 'biopsy clip', 'scattered fibroglandular densities'), 87),
#  (('scattered fibroglandular densities', 'lumpectomy biopsy'), 82),
#  (('heterogeneously dense', 'obscured, oval, circumscribed, round'), 81),
#  (('asymmetry focal', 'scattered fibroglandular densities'), 71),
#  (('asymmetry', 'heterogeneously dense'), 69),
#  (('fatty', 'reduction'), 68),
#  (('fatty', 'lumpectomy'), 66),
#  (('heterogeneously dense', 'asymmetry focal'), 62),
#  (('lumpectomy reduction', 'scattered fibroglandular densities'), 60),
#  (('lumpectomy', 'benign calcification', 'scattered fibroglandular densities'),
#   57),
#  (('fatty', 'benign calcification'), 56),
#  (('asymmetry', 'scattered fibroglandular densities'), 54),
#  (('obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   50),
#  (('reduction biopsy clip', 'scattered fibroglandular densities'), 39),
#  (('heterogeneously dense', 'lumpectomy biopsy'), 38),
#  (('fatty', 'mass'), 37),
#  (('benign calcification', 'extremely dense'), 36),
#  (('heterogeneously dense',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip'),
#   32),
#  (('lymph node', 'scattered fibroglandular densities'), 29),
#  (('heterogeneously dense', 'architectural distortion'), 29),
#  (('lumpectomy', 'mass', 'scattered fibroglandular densities'), 28),
#  (('implant', 'extremely dense'), 25),
#  (('heterogeneously dense', 'lymph node'), 24),
#  (('lumpectomy', 'benign calcification', 'heterogeneously dense'), 23),
#  (('mass', 'benign calcification', 'heterogeneously dense'), 22),
#  (('implant', 'benign calcification', 'heterogeneously dense'), 22),
#  (('oval', 'scattered fibroglandular densities'), 20),
#  (('implant lumpectomy', 'scattered fibroglandular densities'), 20),
#  (('heterogeneously dense', 'grouped'), 19),
#  (('scattered fibroglandular densities', 'architectural distortion'), 19),
#  (('benign calcification', 'biopsy clip', 'extremely dense'), 19),
#  (('heterogeneously dense', 'implant biopsy clip'), 19),
#  (('heterogeneously dense', 'lumpectomy reduction'), 17),
#  (('scattered fibroglandular densities', 'lumpectomy reduction biopsy clip'),
#   17),
#  (('reduction', 'benign calcification', 'scattered fibroglandular densities'),
#   16),
#  (('mass', 'benign calcification', 'scattered fibroglandular densities'), 16),
#  (('heterogeneously dense', 'reduction biopsy clip'), 16),
#  (('reduction biopsy', 'scattered fibroglandular densities'), 16),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'heterogeneously dense'),
#   15),
#  (('heterogeneously dense', 'implant biopsy'), 15),
#  (('implant lumpectomy', 'heterogeneously dense'), 14),
#  (('lumpectomy', 'extremely dense'), 13),
#  (('fatty', 'lumpectomy biopsy clip'), 13),
#  (('obscured, oval, circumscribed, round',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   13),
#  (('benign calcification',
#    'lumpectomy biopsy clip',
#    'scattered fibroglandular densities'),
#   12),
#  (('implant biopsy clip', 'scattered fibroglandular densities'), 11),
#  (('benign calcification', 'lumpectomy biopsy clip', 'heterogeneously dense'),
#   11),
#  (('fatty', 'implant'), 10),
#  (('reduction', 'benign calcification', 'heterogeneously dense'), 10),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   10),
#  (('heterogeneously dense', 'benign calcification', 'mass', 'biopsy clip'),
#   10),
#  (('lumpectomy clip', 'scattered fibroglandular densities'), 9),
#  (('fatty', 'benign calcification', 'biopsy clip'), 8),
#  (('implant reduction', 'scattered fibroglandular densities'), 8),
#  (('mass', 'biopsy clip', 'extremely dense'), 8),
#  (('lumpectomy', 'heterogeneously dense', 'lymph node'), 8),
#  (('implant', 'heterogeneously dense', 'mass'), 8),
#  (('heterogeneously dense', 'oval'), 8),
#  (('grouped', 'scattered fibroglandular densities'), 8),
#  (('implant', 'benign calcification', 'scattered fibroglandular densities'),
#   7),
#  (('mass', 'extremely dense'), 7),
#  (('fatty', 'benign calcification', 'reduction'), 7),
#  (('implant reduction', 'heterogeneously dense'), 7),
#  (('benign calcification',
#    'reduction biopsy clip',
#    'scattered fibroglandular densities'),
#   7),
#  (('mass',
#    'benign calcification',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   7),
#  (('fatty', 'reduction biopsy'), 7),
#  (('reduction', 'extremely dense'), 7),
#  (('implant biopsy', 'scattered fibroglandular densities'), 7),
#  (('heterogeneously dense', 'reduction biopsy'), 7),
#  (('lymph node', 'biopsy clip', 'scattered fibroglandular densities'), 7),
#  (('lumpectomy', 'heterogeneously dense', 'mass'), 6),
#  (('reduction', 'benign calcification', 'extremely dense'), 6),
#  (('fatty', 'reduction biopsy clip'), 6),
#  (('lumpectomy', 'lymph node', 'scattered fibroglandular densities'), 6),
#  (('mass', 'lumpectomy biopsy clip', 'scattered fibroglandular densities'), 6),
#  (('lumpectomy biopsy clip', 'extremely dense'), 6),
#  (('implant', 'mass', 'scattered fibroglandular densities'), 6),
#  (('fatty', 'asymmetry focal'), 6),
#  (('vascular, benign calcification', 'scattered fibroglandular densities'), 5),
#  (('fatty', 'benign calcification', 'lumpectomy'), 5),
#  (('asymmetry', 'scattered fibroglandular densities', 'benign calcification'),
#   5),
#  (('fatty', 'lymph node'), 5),
#  (('benign calcification', 'heterogeneously dense', 'lumpectomy biopsy'), 5),
#  (('fatty', 'mass', 'reduction'), 5),
#  (('extremely dense', 'lumpectomy biopsy'), 5),
#  (('obscured, oval, circumscribed, round', 'extremely dense'), 5),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip',
#    'extremely dense'),
#   5),
#  (('grouped', 'heterogeneously dense', 'biopsy clip'), 5),
#  (('asymmetry', 'extremely dense'), 5),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'extremely dense'),
#   5),
#  (('benign calcification',
#    'lumpectomy reduction',
#    'scattered fibroglandular densities'),
#   5),
#  (('fatty', 'lumpectomy biopsy'), 5),
#  (('heterogeneously dense', 'asymmetry focal', 'biopsy clip'), 5),
#  (('vascular, benign calcification', 'heterogeneously dense'), 4),
#  (('fatty', 'benign calcification', 'mass'), 4),
#  (('implant', 'asymmetry', 'scattered fibroglandular densities'), 4),
#  (('heterogeneously dense', 'skin lesion'), 4),
#  (('fatty', 'mass', 'biopsy clip'), 4),
#  (('mass', 'lymph node', 'scattered fibroglandular densities'), 4),
#  (('fatty', 'asymmetry'), 4),
#  (('reduction', 'mass', 'scattered fibroglandular densities'), 4),
#  (('lumpectomy',
#    'heterogeneously dense',
#    'obscured, oval, circumscribed, round'),
#   4),
#  (('implant biopsy clip lumpectomy', 'heterogeneously dense'), 4),
#  (('benign calcification',
#    'scattered fibroglandular densities',
#    'lumpectomy biopsy'),
#   4),
#  (('scattered fibroglandular densities',
#    'asymmetry focal',
#    'architectural distortion'),
#   4),
#  (('heterogeneously dense', 'lumpectomy reduction biopsy clip'), 4),
#  (('fatty', 'obscured, oval, circumscribed, round'), 4),
#  (('implant', 'heterogeneously dense', 'obscured, oval, circumscribed, round'),
#   4),
#  (('lumpectomy', 'heterogeneously dense', 'skin thickening'), 4),
#  (('scattered fibroglandular densities', 'lymph node', 'lumpectomy biopsy'),
#   4),
#  (('implant',), 3),
#  (('heterogeneously dense', 'vascular'), 3),
#  (('scattered fibroglandular densities', 'lymph node', 'node'), 3),
#  (('fatty', 'lymph node', 'biopsy clip'), 3),
#  (('scattered fibroglandular densities', 'round'), 3),
#  (('benign calcification', 'lymph node', 'scattered fibroglandular densities'),
#   3),
#  (('extremely dense', 'architectural distortion'), 3),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   3),
#  (('mass', 'heterogeneously dense', 'lumpectomy biopsy clip'), 3),
#  (('lymph node',
#    'lumpectomy biopsy clip',
#    'scattered fibroglandular densities'),
#   3),
#  (('reduction biopsy clip', 'extremely dense'), 3),
#  (('lumpectomy', 'skin thickening', 'scattered fibroglandular densities'), 3),
#  (('heterogeneously dense', 'implant clip'), 3),
#  (('lumpectomy',
#    'trabecular thickening',
#    'scattered fibroglandular densities'),
#   3),
#  (('oval', 'lymph node', 'scattered fibroglandular densities'), 3),
#  (('lumpectomy', 'asymmetry', 'scattered fibroglandular densities'), 3),
#  (('mass', 'benign calcification', 'biopsy clip', 'extremely dense'), 3),
#  (('lumpectomy', 'asymmetry focal', 'scattered fibroglandular densities'), 3),
#  (('asymmetry focal', 'biopsy clip', 'scattered fibroglandular densities'), 3),
#  (('implant biopsy lumpectomy', 'scattered fibroglandular densities'), 3),
#  (('fatty', 'grouped', 'biopsy clip'), 3),
#  (('lumpectomy', 'heterogeneously dense', 'grouped'), 3),
#  (('benign calcification',
#    'post operative finding',
#    'scattered fibroglandular densities'),
#   2),
#  (('vascular', 'scattered fibroglandular densities'), 2),
#  (('oval, circumscribed, round', 'scattered fibroglandular densities'), 2),
#  (('grouped', 'extremely dense'), 2),
#  (('skin, benign calcification', 'scattered fibroglandular densities'), 2),
#  (('obscured, round', 'heterogeneously dense'), 2),
#  (('circumscribed', 'scattered fibroglandular densities'), 2),
#  (('mass', 'lumpectomy reduction', 'scattered fibroglandular densities'), 2),
#  (('mass', 'scattered fibroglandular densities', 'lumpectomy biopsy'), 2),
#  (('heterogeneously dense', 'round'), 2),
#  (('implant biopsy', 'extremely dense'), 2),
#  (('lumpectomy',
#    'dystrophic, benign calcification',
#    'scattered fibroglandular densities'),
#   2),
#  (('mass', 'heterogeneously dense', 'lymph node'), 2),
#  (('fatty', 'skin lesion'), 2),
#  (('implant biopsy clip', 'extremely dense'), 2),
#  (('obscured', 'scattered fibroglandular densities'), 2),
#  (('mass', 'implant biopsy clip', 'scattered fibroglandular densities'), 2),
#  (('reduction',
#    'obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   2),
#  (('asymmetry global', 'scattered fibroglandular densities'), 2),
#  (('heterogeneously dense', 'oval, circumscribed, equal density'), 2),
#  (('benign calcification', 'reduction biopsy clip', 'heterogeneously dense'),
#   2),
#  (('scattered fibroglandular densities', 'asymmetry developing'), 2),
#  (('heterogeneously dense', 'lymph node', 'lumpectomy biopsy'), 2),
#  (('heterogeneously dense', 'lymph node', 'biopsy clip'), 2),
#  (('mass', 'asymmetry focal', 'scattered fibroglandular densities'), 2),
#  (('mass',
#    'benign calcification',
#    'lumpectomy reduction',
#    'scattered fibroglandular densities'),
#   2),
#  (('asymmetry', 'biopsy clip', 'scattered fibroglandular densities'), 2),
#  (('obscured, oval', 'scattered fibroglandular densities'), 2),
#  (('lumpectomy',
#    'asymmetry',
#    'skin thickening',
#    'scattered fibroglandular densities'),
#   2),
#  (('implant', 'asymmetry', 'extremely dense'), 2),
#  (('benign calcification',
#    'scattered fibroglandular densities',
#    'lumpectomy reduction biopsy clip'),
#   2),
#  (('fatty', 'lumpectomy reduction'), 2),
#  (('mass', 'scattered fibroglandular densities', 'architectural distortion'),
#   2),
#  (('amorphous, grouped', 'scattered fibroglandular densities'), 2),
#  (('asymmetry',
#    'scattered fibroglandular densities',
#    'architectural distortion'),
#   2),
#  (('reduction clip', 'scattered fibroglandular densities'), 2),
#  (('grouped, benign calcification', 'heterogeneously dense', 'biopsy clip'),
#   2),
#  (('implant', 'benign calcification', 'extremely dense'), 2),
#  (('skin lesion', 'scattered fibroglandular densities'), 2),
#  (('skin thickening', 'scattered fibroglandular densities'), 2),
#  (('heterogeneously dense',
#    'benign calcification',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip'),
#   2),
#  (('reduction', 'asymmetry focal', 'scattered fibroglandular densities'), 2),
#  (('linear', 'scattered fibroglandular densities'), 2),
#  (('heterogeneously dense', 'circumscribed, round'), 2),
#  (('lumpectomy', 'heterogeneously dense', 'architectural distortion'), 2),
#  (('lumpectomy', 'grouped', 'scattered fibroglandular densities'), 2),
#  (('heterogeneously dense',
#    'oval, circumscribed, equal density',
#    'biopsy clip'),
#   2),
#  (('benign calcification', 'post operative finding', 'heterogeneously dense'),
#   1),
#  (('vascular, benign calcification',
#    'post operative finding',
#    'scattered fibroglandular densities'),
#   1),
#  (('heterogeneously dense', 'possible, circumscribed'), 1),
#  (('asymmetry',
#    'scattered fibroglandular densities',
#    'biopsy clip',
#    'benign calcification'),
#   1),
#  (('fatty', 'implant', 'lymph node'), 1),
#  (('circumscribed, equal density', 'scattered fibroglandular densities'), 1),
#  (('mass',
#    'heterogeneously dense',
#    'vascular, benign calcification',
#    'post operative finding'),
#   1),
#  (('fatty', 'vascular, benign calcification'), 1),
#  (('implant', 'heterogeneously dense', 'oval, circumscribed'), 1),
#  (('implant',
#    'vascular, benign calcification',
#    'intramammary node',
#    'scattered fibroglandular densities'),
#   1),
#  (('asymmetry', 'extremely dense', 'biopsy clip', 'benign calcification'), 1),
#  (('lumpectomy',), 1),
#  (('fatty', 'asymmetry', 'grouped'), 1),
#  (('asymmetry focal', 'irregular', 'scattered fibroglandular densities'), 1),
#  (('heterogeneously dense', 'skin, vascular'), 1),
#  (('heterogeneously dense', 'intramammary node'), 1),
#  (('diffuse', 'heterogeneously dense'), 1),
#  (('implant', 'lymph node', 'scattered fibroglandular densities'), 1),
#  (('diffuse', 'lumpectomy', 'scattered fibroglandular densities'), 1),
#  (('heterogeneously dense', 'diffuse, vascular, benign calcification'), 1),
#  (('oval, round', 'scattered fibroglandular densities'), 1),
#  (('mass', 'heterogeneously dense', 'implant biopsy clip'), 1),
#  (('heterogeneously dense', 'lymph node', 'node'), 1),
#  (('mass', 'dystrophic, benign calcification', 'heterogeneously dense'), 1),
#  (('asymmetry focal', 'extremely dense'), 1),
#  (('heterogeneously dense', 'oval, fat-containing, microlobulated'), 1),
#  (('linear, fine-linear, grouped', 'scattered fibroglandular densities'), 1),
#  (('fatty', 'asymmetry', 'benign calcification'), 1),
#  (('heterogeneously dense',
#    'lumpectomy biopsy clip',
#    'architectural distortion'),
#   1),
#  (('oval, fat-containing, circumscribed',
#    'scattered fibroglandular densities'),
#   1),
#  (('mass',
#    'benign calcification',
#    'lymph node',
#    'scattered fibroglandular densities'),
#   1),
#  (('heterogeneously dense', 'diffuse, benign calcification', 'biopsy clip'),
#   1),
#  (('fatty', 'reduction', 'fat-containing'), 1),
#  (('benign calcification',
#    'implant biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('obscured, oval, equal density',
#    'asymmetry',
#    'scattered fibroglandular densities'),
#   1),
#  (('mass', 'benign calcification', 'extremely dense'), 1),
#  (('heterogeneously dense',
#    'diffuse, benign calcification',
#    'obscured, oval, circumscribed, round'),
#   1),
#  (('heterogeneously dense', 'asymmetry', 'biopsy clip'), 1),
#  (('implant', 'heterogeneously dense', 'asymmetry focal'), 1),
#  (('scattered fibroglandular densities', 'biopsy clip', 'round'), 1),
#  (('mass', 'heterogeneously dense', 'asymmetry focal'), 1),
#  (('fatty', 'mass', 'lymph node'), 1),
#  (('round', 'heterogeneously dense', 'benign calcification, round'), 1),
#  (('lumpectomy', 'heterogeneously dense', 'vascular, benign calcification'),
#   1),
#  (('round, oval, circumscribed, node',
#    'lymph node',
#    'scattered fibroglandular densities'),
#   1),
#  (('fatty', 'lumpectomy', 'skin thickening, lymph node'), 1),
#  (('benign calcification', 'lymph node', 'heterogeneously dense'), 1),
#  (('lymph node',
#    'biopsy clip',
#    'node',
#    'benign calcification',
#    'scattered fibroglandular densities'),
#   1),
#  (('implant', 'rim', 'scattered fibroglandular densities'), 1),
#  (('implant', 'dystrophic', 'scattered fibroglandular densities'), 1),
#  (('diffuse, benign calcification', 'extremely dense'), 1),
#  (('lumpectomy clip',), 1),
#  (('heterogeneously dense', 'implant reduction biopsy clip'), 1),
#  (('fatty', 'implant reduction', 'lymph node', 'mass'), 1),
#  (('implant lumpectomy', 'benign calcification', 'heterogeneously dense'), 1),
#  (('fatty', 'implant biopsy'), 1),
#  (('mass', 'lumpectomy biopsy clip', 'extremely dense'), 1),
#  (('dystrophic, benign calcification',
#    'scattered fibroglandular densities',
#    'biopsy clip',
#    'architectural distortion'),
#   1),
#  (('heterogeneously dense',
#    'lumpectomy biopsy clip',
#    'obscured, oval, circumscribed, round'),
#   1),
#  (('fatty', 'architectural distortion'), 1),
#  (('mass', 'asymmetry', 'extremely dense'), 1),
#  (('implant biopsy', 'lymph node', 'scattered fibroglandular densities'), 1),
#  (('fatty', 'lumpectomy', 'lymph node'), 1),
#  (('scattered fibroglandular densities',
#    'lymph node',
#    'lumpectomy reduction biopsy clip'),
#   1),
#  (('lymph node', 'extremely dense', 'lumpectomy biopsy'), 1),
#  (('benign calcification',
#    'lumpectomy reduction',
#    'obscured, oval, circumscribed, round',
#    'heterogeneously dense'),
#   1),
#  (('heterogeneously dense', 'asymmetry focal', 'post operative finding'), 1),
#  (('heterogeneously dense', 'biopsy clip', 'round'), 1),
#  (('fatty', 'circumscribed'), 1),
#  (('oval, obscured, high density', 'heterogeneously dense'), 1),
#  (('lumpectomy', 'dystrophic', 'scattered fibroglandular densities'), 1),
#  (('scattered fibroglandular densities',
#    'obscured, oval, circumscribed, round',
#    'benign calcification, round'),
#   1),
#  (('scattered fibroglandular densities',
#    'biopsy clip',
#    'benign calcification, round'),
#   1),
#  (('heterogeneously dense', 'lymph node', 'oval, node'), 1),
#  (('skin, benign calcification',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('fatty', 'benign calcification', 'lymph node'), 1),
#  (('asymmetry', 'lumpectomy biopsy clip', 'heterogeneously dense'), 1),
#  (('heterogeneously dense', 'lumpectomy clip', 'lymph node'), 1),
#  (('implant reduction',
#    'benign calcification',
#    'scattered fibroglandular densities'),
#   1),
#  (('asymmetry',
#    'lumpectomy biopsy clip',
#    'scattered fibroglandular densities',
#    'benign calcification'),
#   1),
#  (('fine-linear, linear', 'heterogeneously dense'), 1),
#  (('lumpectomy clip',
#    'skin thickening',
#    'benign calcification',
#    'scattered fibroglandular densities',
#    'asymmetry'),
#   1),
#  (('indistinct', 'scattered fibroglandular densities'), 1),
#  (('benign calcification',
#    'heterogeneously dense',
#    'architectural distortion'),
#   1),
#  (('scattered fibroglandular densities',
#    'biopsy clip',
#    'architectural distortion'),
#   1),
#  (('lumpectomy',
#    'skin thickening',
#    'benign calcification',
#    'scattered fibroglandular densities',
#    'asymmetry'),
#   1),
#  (('fatty', 'benign calcification', 'lumpectomy reduction'), 1),
#  (('heterogeneously dense', 'oval, round'), 1),
#  (('implant', 'heterogeneously dense', 'architectural distortion'), 1),
#  (('lumpectomy', 'asymmetry', 'skin thickening', 'extremely dense'), 1),
#  (('fatty', 'asymmetry', 'lumpectomy', 'skin thickening'), 1),
#  (('lumpectomy', 'asymmetry', 'skin thickening', 'heterogeneously dense'), 1),
#  (('oval, circumscribed', 'scattered fibroglandular densities'), 1),
#  (('lumpectomy', 'heterogeneously dense', 'asymmetry focal'), 1),
#  (('implant reduction', 'benign calcification', 'heterogeneously dense'), 1),
#  (('heterogeneously dense', 'linear, round'), 1),
#  (('diffuse', 'heterogeneously dense', 'biopsy clip'), 1),
#  (('fatty', 'equal density'), 1),
#  (('irregular, spiculated', 'heterogeneously dense'), 1),
#  (('grouped, benign calcification', 'heterogeneously dense'), 1),
#  (('implant reduction lumpectomy biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('asymmetry', 'extremely dense', 'biopsy clip', 'architectural distortion'),
#   1),
#  (('implant biopsy clip',
#    'obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   1),
#  (('mass',
#    'benign calcification',
#    'lumpectomy biopsy clip',
#    'heterogeneously dense'),
#   1),
#  (('fatty', 'implant biopsy clip lumpectomy'), 1),
#  (('irregular', 'scattered fibroglandular densities'), 1),
#  (('low density', 'biopsy clip', 'scattered fibroglandular densities'), 1),
#  (('heterogeneously dense', 'irregular'), 1),
#  (('benign calcification',
#    'trabecular thickening',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('fatty', 'benign calcification', 'implant lumpectomy'), 1),
#  (('fatty', 'mass', 'lumpectomy biopsy clip'), 1),
#  (('fatty', 'mass', 'lumpectomy'), 1),
#  (('implant', 'asymmetry', 'heterogeneously dense'), 1),
#  (('heterogeneously dense', 'circumscribed'), 1),
#  (('heterogeneously dense', 'skin, benign calcification'), 1),
#  (('mass', 'asymmetry', 'scattered fibroglandular densities'), 1),
#  (('lumpectomy',
#    'benign calcification',
#    'mass',
#    'scattered fibroglandular densities'),
#   1),
#  (('heterogeneously dense', 'obscured, oval'), 1),
#  (('fatty', 'benign calcification', 'implant biopsy'), 1),
#  (('lumpectomy',
#    'scattered fibroglandular densities',
#    'large, dystrophic, benign calcification'),
#   1),
#  (('mass',
#    'lumpectomy clip',
#    'lymph node',
#    'scattered fibroglandular densities'),
#   1),
#  (('heterogeneously dense', 'lumpectomy clip'), 1),
#  (('implant', 'heterogeneously dense', 'round'), 1),
#  (('heterogeneously dense', 'biopsy clip', 'architectural distortion'), 1),
#  (('benign calcification', 'lumpectomy reduction', 'heterogeneously dense'),
#   1),
#  (('benign calcification', 'reduction biopsy clip', 'extremely dense'), 1),
#  (('mass', 'implant biopsy clip', 'extremely dense'), 1),
#  (('lumpectomy',
#    'obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   1),
#  (('fatty', 'benign calcification', 'implant reduction'), 1),
#  (('lumpectomy',
#    'benign calcification',
#    'lymph node',
#    'scattered fibroglandular densities'),
#   1),
#  (('obscured, oval, circumscribed, round', 'biopsy clip', 'extremely dense'),
#   1),
#  (('implant', 'scattered fibroglandular densities', 'lymph node', 'node'), 1),
#  (('lumpectomy reduction', 'lymph node', 'scattered fibroglandular densities'),
#   1),
#  (('fatty', 'benign calcification', 'reduction biopsy clip'), 1),
#  (('asymmetry',), 1),
#  (('benign calcification',
#    'lumpectomy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('implant reduction lumpectomy', 'scattered fibroglandular densities'), 1),
#  (('heterogeneously dense',
#    'implant biopsy',
#    'obscured, oval, circumscribed, round'),
#   1),
#  (('grouped, benign calcification, round',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('grouped', 'heterogeneously dense', 'mass', 'biopsy clip'), 1),
#  (('lymph node', 'lumpectomy biopsy clip', 'extremely dense'), 1),
#  (('fatty', 'benign calcification', 'reduction biopsy'), 1),
#  (('heterogeneously dense', 'milk of calcium, benign calcification'), 1),
#  (('implant', 'asymmetry focal', 'scattered fibroglandular densities'), 1),
#  (('implant biopsy clip lumpectomy', 'heterogeneously dense', 'lymph node'),
#   1),
#  (('fatty', 'lumpectomy reduction biopsy clip'), 1),
#  (('scattered fibroglandular densities', 'implant biopsy clip', 'round'), 1),
#  (('benign calcification', 'implant biopsy', 'heterogeneously dense'), 1),
#  (('lumpectomy', 'heterogeneously dense', 'skin'), 1),
#  (('mass', 'heterogeneously dense', 'reduction clip'), 1),
#  (('implant', 'scattered fibroglandular densities', 'round'), 1),
#  (('reduction', 'grouped', 'scattered fibroglandular densities'), 1),
#  (('skin thickening',
#    'lumpectomy biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('dystrophic, benign calcification', 'heterogeneously dense'), 1),
#  (('biopsy clip',), 1),
#  (('mass', 'heterogeneously dense', 'reduction'), 1),
#  (('fatty', 'skin, benign calcification'), 1),
#  (('heterogeneously dense', 'lymph node', 'obscured, circumscribed, node'), 1),
#  (('grouped, round',
#    'circumscribed, round',
#    'scattered fibroglandular densities'),
#   1),
#  (('heterogeneously dense', 'high density, circumscribed, round'), 1),
#  (('mass', 'asymmetry', 'heterogeneously dense'), 1),
#  (('mass', 'benign calcification', 'reduction', 'heterogeneously dense'), 1),
#  (('oval', 'biopsy clip', 'extremely dense'), 1),
#  (('benign calcification',
#    'oval, circumscribed, equal density',
#    'heterogeneously dense'),
#   1),
#  (('heterogeneously dense', 'trabecular thickening', 'lumpectomy biopsy clip'),
#   1),
#  (('lumpectomy',
#    'mass',
#    'heterogeneously dense',
#    'benign calcification',
#    'trabecular thickening, skin thickening'),
#   1),
#  (('fatty', 'mass', 'reduction biopsy clip'), 1),
#  (('oval',
#    'lumpectomy biopsy clip',
#    'grouped',
#    'scattered fibroglandular densities'),
#   1),
#  (('obscured, oval, equal density', 'biopsy clip', 'extremely dense'), 1),
#  (('fatty', 'asymmetry', 'mass'), 1),
#  (('oval, circumscribed, equal density', 'scattered fibroglandular densities'),
#   1),
#  (('fatty', 'asymmetry', 'lumpectomy'), 1),
#  (('implant', 'mass', 'extremely dense'), 1),
#  (('linear', 'lumpectomy biopsy clip', 'scattered fibroglandular densities'),
#   1),
#  (('heterogeneously dense', 'skin thickening, architectural distortion'), 1),
#  (('heterogeneously dense', 'asymmetry focal', 'architectural distortion'), 1),
#  (('asymmetry focal',
#    'lumpectomy biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('spiculated', 'scattered fibroglandular densities'), 1),
#  (('oval, obscured, high density', 'extremely dense'), 1),
#  (('fatty', 'oval'), 1),
#  (('indistinct, irregular', 'scattered fibroglandular densities'), 1),
#  (('mass', 'heterogeneously dense', 'architectural distortion'), 1),
#  (('lumpectomy',
#    'scattered fibroglandular densities',
#    'asymmetry focal',
#    'architectural distortion'),
#   1),
#  (('fatty', 'reduction', 'oval'), 1),
#  (('dystrophic, benign calcification',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   1),
#  (('heterogeneously dense', 'regional', 'architectural distortion'), 1),
#  (('heterogeneously dense',
#    'asymmetry focal',
#    'obscured, oval, circumscribed, round'),
#   1),
#  (('lumpectomy', 'popcorn, regional', 'scattered fibroglandular densities'),
#   1),
#  (('lumpectomy biopsy',
#    'asymmetry focal',
#    'scattered fibroglandular densities',
#    'architectural distortion'),
#   1),
#  (('heterogeneously dense', 'oval, equal density'), 1),
#  (('benign calcification',
#    'asymmetry focal',
#    'scattered fibroglandular densities'),
#   1),
#  (('lumpectomy',
#    'scattered fibroglandular densities',
#    'architectural distortion'),
#   1),
#  (('heterogeneously dense', 'oval', 'biopsy clip'), 1),
#  (('oval', 'biopsy clip', 'scattered fibroglandular densities'), 1),
#  (('mass',
#    'lumpectomy biopsy clip',
#    'skin lesion',
#    'scattered fibroglandular densities'),
#   1),
#  (('asymmetry', 'heterogeneously dense', 'architectural distortion'), 1),
#  (('spiculated, round', 'scattered fibroglandular densities'), 1),
#  (('lumpectomy', 'circumscribed', 'scattered fibroglandular densities'), 1),
#  (('heterogeneously dense', 'segmental'), 1),
#  (('obscured, oval, equal density', 'scattered fibroglandular densities'), 1),
#  (('asymmetry focal', 'reduction biopsy clip', 'extremely dense'), 1),
#  (('grouped',
#    'scattered fibroglandular densities',
#    'biopsy clip',
#    'architectural distortion'),
#   1),
#  (('heterogeneously dense', 'asymmetry developing'), 1),
#  (('amorphous, grouped', 'heterogeneously dense'), 1),
#  (('heterogeneously dense',
#    'asymmetry focal',
#    'indistinct, equal density, round'),
#   1),
#  (('extremely dense', 'biopsy clip', 'architectural distortion'), 1),
#  (('heterogeneously dense', 'indistinct, irregular, equal density'), 1),
#  (('reduction',
#    'asymmetry',
#    'heterogeneously dense',
#    'architectural distortion'),
#   1),
#  (('mass',
#    'rim, benign calcification',
#    'scattered fibroglandular densities',
#    'lumpectomy biopsy'),
#   1),
#  (('trabecular thickening, lymph node', 'scattered fibroglandular densities'),
#   1),
#  (('scattered fibroglandular densities',
#    'obscured, oval, circumscribed, round',
#    'architectural distortion'),
#   1)]

# %%
#printing finding with extracted groups
for i in range(2000):
    if df.iloc[i]["caption"] is not None:
        print("FINDING: ")
        print(df.iloc[i]["caption"])
        print("GROUP: {group}".format(group = df.iloc[i]["GROUP"]))
        print("\n")
# Out:
# FINDING:
# the breasts have scattered areas of fibroglandular density.   left asymmetry: there is an asymmetry seen in the left breast on the cc view which is circumscribed and measures 6mm.   this is a newly visualized finding. this may have been too far posterior to be visualized on prior mammogram.  right there are no significant masses, calcifications, or other findings.  there are no other significant masses, calcifications, or other findings.
# GROUP: ('asymmetry', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in both breasts.  there also are post operative findings in the right breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('benign calcification', 'post operative finding', 'heterogeneously dense')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in both breasts.  there also are post operative findings in the left breast.   no significant masses, calcifications, or other findings are seen in either breast.   repeat     view is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of the right breast as described above.
# GROUP: ('benign calcification', 'post operative finding', 'scattered fibroglandular densities')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in both breasts.  there also are post operative findings and a biopsy clip in the right breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('benign calcification', 'biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   there is a biopsy clip in the left breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
#    the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   right xccl view is needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.    repeat left mlo view is needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of the left breast as described above.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.     repeat both mlo views are needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of both breasts as described above.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there is a 5 mm irregular asymmetry in the left breast at 11 o'clock middle depth.   no other significant masses, calcifications, or other findings are seen in either breast.     the 5 mm irregular asymmetry in the left breast appears indeterminate.  additional views with possible ultrasound are recommended.
# GROUP: ('asymmetry', 'heterogeneously dense')
#
#
# FINDING:
#    the tissue of both breasts is predominantly fatty.   current study was also evaluated with a computer aided detection   system.     repeat rcc view is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   repeat cc view of the right breast is required for positioning. complete interpretation and dictation will follow after technical repeat imaging.
# GROUP: ('fatty',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there are benign vascular calcifications in both breasts.  there also are post operative findings in the left breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('vascular, benign calcification', 'post operative finding', 'scattered fibroglandular densities')
#
#
# FINDING:
#  the tissue of the right breast is heterogeneously dense. this may lower the sensitivity of mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there is a possible developing mass with a circumscribed margin in the right breast at 5 o'clock anterior depth.   no other significant masses or calcifications are seen in the breast.     the possible developing mass in the right breast appears indeterminate.  mediolateral and compression views as well as an ultrasound are recommended.
# GROUP: ('heterogeneously dense', 'possible, circumscribed')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#    there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   repeat right cc view is needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging. no significant masses, calcifications, or other findings are seen in either breast.     suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of the right breast as described above.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   repeat bilateral cc views are needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging. no significant masses, calcifications, or other findings are seen in either breast.     suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of the both breasts as described above.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  the tissue of both breasts is predominantly fatty.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there is a mole marker on the right breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('fatty',)
#
#
# FINDING:
#  the tissue of the right breast is heterogeneously dense. this may lower the sensitivity of mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there are benign vascular calcifications and calcifications in the right breast.   no significant masses, calcifications, or other findings are seen in the breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('vascular, benign calcification', 'heterogeneously dense')
#
#
# FINDING:
#  the tissue of the left breast is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there is a marker clip in the appropriate position in the left breast at 12 o'clock middle depth.  this marker clip placement is at biopsy site.
# GROUP: ('heterogeneously dense', 'biopsy clip')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.     repeat left cc view is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of the left breast as described above.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   repeat right mlo and left cc view is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   repeat images for motion.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in the right breast that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   there are benign vascular calcifications and calcifications in the right breast.   no significant masses, calcifications, or other findings are seen in the breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('vascular, benign calcification', 'scattered fibroglandular densities')
#
#
# FINDING:
#  the tissue of the left breast is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in the left breast.   no significant masses, calcifications, or other findings are seen in the breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('benign calcification', 'heterogeneously dense')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   a benign appearing calcification is present in the right breast.  examination indicates a biopsy marker in the right breast.   there is a 1.1 cm oval asymmetry with a macrolobulated margin in the right breast middle depth central to the nipple seen on the craniocaudal view only.   no other significant masses, calcifications, or other findings are seen in either breast.     the 1.1 cm oval asymmetry in the right breast appears indeterminate.  additional views with possible ultrasound are recommended.
# GROUP: ('asymmetry', 'scattered fibroglandular densities', 'biopsy clip', 'benign calcification')
#
#
# FINDING:
#  the tissue of the right breast is predominantly fatty.   current study was also evaluated with a computer aided detection   system.   routine and push back technique is utilized. bilateral implants are present. no significant change in the mammogram is seen, there are a few to several coarse calcifications associated with probable fibroadenomas, unchanged. there is a densely coarsely calcified fibroadenoma seen in the deep outer mid aspect of the right breast near the implant, also unchanged.   us had been prescribed to re-evaluate a proable fibroadenoma, seen in the 9 oclock region 2 cmfn.    right breast targeted us:   10 oclock 2 cmfn: 1.01 x .68 x .49 cm nodule with calcifications--unchanged 9 oclock 2 cmfn: .88x x .75 x .30 cm nodule withou calcifications-unchanged 8 oclock 4 cmfn: 1.26 x .71 x .97 cm nodule paritally calcified-unchanged 8 oclock 5 cmfn: .82 x .28 x .75cm lymph node with fatty hilum-, unchanged all of the above are unchanged over 2 years time.
# GROUP: ('fatty', 'implant', 'lymph node')
#
#
# FINDING:
#  there are scattered fibroglandular elements in the right breast that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   there is a biopsy clip in the right breast.   no significant masses, calcifications, or other findings are seen in the breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
#  south, 7/7/2014 mammogram, and 7/3/2013 mammogram - uw health  east towne.     there are scattered fibroglandular elements in both breasts that could obscure a  lesion on mammography.     repeat right cc and left mlo views are needed for technical reasons. the details  for the repeat view  have been entered into the pacs exam qa section.  complete interpretation and dictation will follow after technical repeat  imaging.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  uw health imaging 1 south, 11/9/2011 mammogram - uw health yahara, 9/16/2009  mammogram - uw health imaging 1 south, 9/8/2008 mammogram - uw health 20 s park  3rd floor, and 9/26/2007 mammogram - uw health imaging 1 south.   there are scattered fibroglandular elements in both breasts that could obscure a  lesion on mammography.   current study was also evaluated with a computer aided detection   system.   repeat left mlo view is needed for technical reasons  . the details for the repeat  view  have been entered into the pacs exam qa section. complete interpretation  and dictation will follow after technical repeat imaging.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#    the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.      repeat imaging of both breasts is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.    repeat mlo view of both breasts is required for motion.  repeat xccl view of the right breast is required for positioning.   suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of both breasts as described above.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#    there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   repeat bilateral cc views are needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of both breasts as described above.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   repeat right cc view is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   repeat right cc for motion.  technical recall.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   routine and push back technique is utilized. bilateral implants are present.   there is a benign nodule in the right breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.
# GROUP: ('implant', 'heterogeneously dense')
#
#
# FINDING:
#    the tissue of the left breast is extremely dense, which lowers the sensitivity of mammography.     repeat left cc view is needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   repeat cc view of the left breast is required for positioning.  complete interpretation and dictation will follow after technical repeat imaging.
# GROUP: ('extremely dense',)
#
#
# FINDING:
#    there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.     repeat right cc with implant included and left mlo with implant included views are needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.     suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of the both breasts as described above.
# GROUP: ('implant', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are almost entirely fatty.   there are benign post-lumpectomy findings in the right breast. there are typically benign calcifications in both breasts.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('fatty', 'benign calcification', 'lumpectomy')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   left mass: there is an equal density mass with circumscribed margins seen in the left breast at 1 o'clock in the middle depth. compared to the previous study, there are no significant changes. associated features include calcifications. there are developing  calcifications suggesting this is a degenerating fibroadenoma.   right there are no significant masses, calcifications, or other findings.  there are no other significant masses, calcifications, or other findings.
# GROUP: ('circumscribed, equal density', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are typically benign calcifications in both breasts.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('benign calcification', 'heterogeneously dense')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.  stable retropectoral saline implants bilaterally.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('implant', 'heterogeneously dense')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there is a focal asymmetry in the right breast at 9 o'clock middle depth with a suggestion of some subtle architectural change.
# GROUP: ('heterogeneously dense', 'asymmetry focal')
#
#
# FINDING:
#  the tissue of both breasts is predominantly fatty.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in both breasts.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('fatty', 'benign calcification')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   additional view  were obtained to optimize the technique of the exam.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#    additional bilateral mlo views were repeated for technical reasons, and are read in conjunction with the standard views from recent screening mammogram dated 2/9/2017.   current study was also evaluated with a computer aided detection   system.    there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.     no significant masses, calcifications, or other findings are seen in either breast.     there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  the tissue of the right breast is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there is a focal asymmetry in the right breast central to the nipple middle depth.  this is not seen in additional views.   this abnormality was not seen on targeted ultrasound.   no other significant masses or calcifications are seen in the breast on the mammogram or right targeted ultrasound.     overall study birads: 1 negative the focal asymmetry in the right breast is consistent with fibroglandular tissue and appears indeterminate.  an ultrasound is recommended.   routine screening mammography is recommended.
# GROUP: ('heterogeneously dense', 'asymmetry focal')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   repeat left mlo view is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   repeat left mlo view is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses. there is a 9 x 7 mm mass in the left breast at 6 o'clock that is 2.5 cm fn. recommend diagnostic mammogram and us.there are no dominant masses on the right. there are benign  calcifications on the left.
# GROUP: ('mass', 'benign calcification', 'heterogeneously dense')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#    the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.     additional view  were repeated for technical reasons, and are read in conjunction with the standard views from recent screening mammogram.   there are benign calcifications in both breasts.    no significant masses, calcifications, or other findings are seen in either breast.    there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('benign calcification', 'heterogeneously dense')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there are benign vascular calcifications in both breasts.  there also is a benign mass in the left breast.  additionally, there are post operative findings in the right breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('mass', 'heterogeneously dense', 'vascular, benign calcification', 'post operative finding')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there is a possible asymmetry seen in the superior left breast on the mlo projection.  recommend additional views for further evaluation.  there are bilateral benign type calcifications.   no significant masses, calcifications, or other findings are seen in either breast.     recommend left diagnostic mammogram for further evaluation.
# GROUP: ('asymmetry', 'scattered fibroglandular densities', 'benign calcification')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. a 5 year screening mammogram is recommended.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   patient returned for the left cc view due to motion artifact on the 1/31/17 visit.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   no mammographic evidence of malignancy. the patient should return in one year for a screening mammogram.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there is a 6 mm oval mass in the left breast middle depth central to the nipple seen on the mediolateral oblique view only.   no other significant masses, calcifications, or other findings are seen in either breast.     the 6 mm oval mass in the left breast appears indeterminate.  additional views as well as an ultrasound are recommended.
# GROUP: ('oval', 'scattered fibroglandular densities')
#
#
# FINDING:
#  the tissue of both breasts is predominantly fatty.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('fatty',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   bilateral subpectoral saline implants are present.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('implant', 'heterogeneously dense')
#
#
# FINDING:
#    the tissue of both breasts is predominantly fatty.     repeat bilateral mlo views is needed for technical reasons. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   repeat mlo view of both breasts is required for technical reasons. complete interpretation and dictation will follow after technical repeat imaging.
# GROUP: ('fatty',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in the left breast that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   the patient has a personal history of breast cancer.   there are benign calcifications in the left breast.   no significant masses, calcifications, or other findings are seen in the breast.   there has been no significant interval change.   no mammographic evidence of malignancy. the patient should return in one year for a screening mammogram.
# GROUP: ('benign calcification', 'scattered fibroglandular densities')
#
#
# FINDING:
#  uw health odana atrium, 4/22/2014 mammogram - meriter clinic-monona, and  4/18/2013 mammogram - uw health odana atrium.   the tissue of both breasts is heterogeneously dense. this may lower the  sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   patient returned for repeat cc views to optimize the technique of the exam.   there is a benign calcification in the left breast.   no significant masses, calcifications, or other findings are seen in either  breast.   there has been no significant interval change.
# GROUP: ('benign calcification', 'heterogeneously dense')
#
#
# FINDING:
#  the tissue of both breasts is predominantly fatty.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in both breasts.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('fatty', 'benign calcification')
#
#
# FINDING:
#  1/31/2013 mammogram - uw health imaging 1 south, and 4/11/2011 mammogram - uw  health 20 s park 3rd floor.   the tissue of both breasts is extremely dense, which lowers the sensitivity of  mammography.   current study was also evaluated with a computer aided detection   system.   repeat left mlo view is needed for technical reasons  . the details for the repeat view  have been entered into the  pacs exam qa section. complete interpretation and dictation will follow after  technical repeat imaging.
# GROUP: ('extremely dense',)
#
#
# FINDING:
#  uw health imaging 1 south, and 3/7/2012 mammogram - east clinic.   the tissue of both breasts is heterogeneously dense. this may lower the  sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there is a biopsy clip in the left breast.   no significant masses, calcifications, or other findings are seen in either  breast.   there has been no significant interval change.
# GROUP: ('heterogeneously dense', 'biopsy clip')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in the right breast.  there also is a benign calcification in the left breast.  additionally, there are post operative findings in the right breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('benign calcification', 'post operative finding', 'scattered fibroglandular densities')
#
#
# FINDING:
#  the tissue of the left breast is extremely dense, which lowers the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in the breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('extremely dense',)
#
#
# FINDING:
#  and 5/30/2013 mammogram - uw health imaging 1 south.   the tissue of both breasts is heterogeneously dense. this may lower the  sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either  breast.   there has been no significant interval change.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#   12/20/2011 mammogram - uw health imaging 1 south.   there are scattered fibroglandular elements in both breasts that could obscure a  lesion on mammography.   current study was also evaluated with a computer aided detection   system.   a screening digital mammogram with 2d and tomosynthesis images was performed.   post lumpectomy changes are redemonstrated on the left.   no significant masses, calcifications, or other findings are seen in either  breast.
# GROUP: ('lumpectomy', 'scattered fibroglandular densities')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   patient returned for a repeat left cc view as their was motion on the original left cc view from the screening mammogram of 12/4/15.   there is a biopsy clip in the right breast.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   patient returned for a repeat left cc view due to motion on the original view. there is no mammographic evidence of malignancy.  routine screening mammography is recommended.
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there is a biopsy clip in the left breast.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('heterogeneously dense', 'biopsy clip')
#
#
# FINDING:
# the breasts are extremely dense, which lowers the sensitivity of mammography.   there are subpectoral saline implants bilaterally.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('implant', 'extremely dense')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there is a biopsy clip in the left breast.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   right breast subpectoral saline implant.   there are no significant masses, calcifications, or other findings in either breast.
# GROUP: ('implant', 'scattered fibroglandular densities')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   the bilateral cc tomosynthesis vews are otbtained. patient could not tolerate completing the exam and the mlo views were not achieved. comparing just the cc views, no significant change, mass or suspicious calcifications are noted. however, the exam is incomplete without the mlo views which provide an orthogonal compressed view and also include the deeper tissues and lower axillary tissues, which are not included on the cc view.   ideally patient will return for the mlo views. patient at this point, will not be charged for this exam.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   repeat both cc views are needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.   suboptimal study due to technical factors.  the patient will be notified to obtain additional imaging of both breasts as described above.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.     repeat bilateral cc views are needed for technical reasons  . the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   a digital mammogram with 2d and tomosynthesis was performed.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in both breasts.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('benign calcification', 'heterogeneously dense')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there is a new round equal density focal asymmetry with an obscured and circumscribed margin in the right breast at 11 o'clock anterior depth.   no other significant masses, calcifications, or other findings are seen in either breast.     the new round equal density focal asymmetry in the right breast appears indeterminate.  additional views with possible ultrasound are recommended.
# GROUP: ('heterogeneously dense', 'asymmetry focal')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   there is a new focal asymmetry in the right breast at 12 o'clock middle depth.   no other significant masses, calcifications, or other findings are seen in either breast.     the new focal asymmetry in the right breast appears indeterminate.  additional views with possible ultrasound are recommended.
# GROUP: ('heterogeneously dense', 'asymmetry focal')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   there are benign calcifications in both breasts.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('benign calcification', 'scattered fibroglandular densities')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   the left breast calcifications appear vascular on the tomo mlo images, but the calcifications are not seen on the cc view. spot compression and magnification views recommended.  no other worrisome findings.   there is a new calcification in the left breast posterior depth central to the nipple seen on the mediolateral oblique view only.   no other significant masses, calcifications, or other findings are seen in either breast.     the new calcification in the left breast appears indeterminate. additional  magnification views recommended.
# GROUP: ('vascular', 'scattered fibroglandular densities')
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.     additional cc images needed for technical reasons.  the lateral breast tissue is not included on the image. the details for the repeat view  have been entered into the pacs exam qa section. complete interpretation and dictation will follow after technical repeat imaging.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
#  the tissue of both breasts is heterogeneously dense. this may lower the sensitivity of mammography.   current study was also evaluated with a computer aided detection   system.   bilateral breast implants are stable.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('implant', 'heterogeneously dense')
#
#
# FINDING:
#  there are scattered fibroglandular elements in both breasts that could obscure a lesion on mammography.   current study was also evaluated with a computer aided detection   system.   no significant masses, calcifications, or other findings are seen in either breast.   there has been no significant interval change.   there is no mammographic evidence of malignancy. routine screening mammography is recommended.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# ...
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings.
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are almost entirely fatty.   there is a stable benign mass in the right breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('fatty', 'mass')
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings.
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there is a biopsy clip in the right breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense', 'biopsy clip')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there is a biopsy clip in the right breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are benign post-excisional biopsy findings in both breasts.   there are no significant masses, calcifications, or other findings
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are almost entirely fatty.  there are no significant masses, calcifications, or other findings
# GROUP: ('fatty',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there is a biopsy clip in the left breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there is a stable benign mass in the left breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('mass', 'heterogeneously dense')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are extremely dense, which lowers the sensitivity of mammography.   there are no significant masses, calcifications, or other findings
# GROUP: ('extremely dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there is a biopsy clip in the right breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense', 'biopsy clip')
#
#
# FINDING:
# the breasts are almost entirely fatty.   there are no significant masses, calcifications, or other findings
# GROUP: ('fatty',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are benign breast reduction findings in both breasts.   there are no significant masses, calcifications, or other findings
# GROUP: ('reduction', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are almost entirely fatty.   there are benign breast reduction findings in both breasts.   there are no significant masses, calcifications, or other findings
# GROUP: ('fatty', 'reduction')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there is a subpectoral saline implant in both breasts.  there are no significant masses, calcifications, or other findings
# GROUP: ('implant', 'heterogeneously dense')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are benign post-excisional biopsy findings in the right breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('biopsy clip', 'scattered fibroglandular densities')
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are almost entirely fatty.   there are benign post-excisional biopsy findings in the left breast.   there are no significant masses, calcifications, or other findings
# GROUP: ('fatty', 'biopsy clip')
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are extremely dense, which lowers the sensitivity of mammography.   there are typically benign calcifications in both breasts.   there are no significant masses, calcifications, or other findings
# GROUP: ('benign calcification', 'extremely dense')
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are almost entirely fatty.   there are no significant masses, calcifications, or other findings
# GROUP: ('fatty',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are almost entirely fatty.   there are no significant masses, calcifications, or other findings
# GROUP: ('fatty',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)
#
#
# FINDING:
# the breasts are almost entirely fatty.   there are no significant masses, calcifications, or other findings
# GROUP: ('fatty',)
#
#
# FINDING:
# the breasts have scattered areas of fibroglandular density.   there are no significant masses, calcifications, or other findings
# GROUP: ('scattered fibroglandular densities',)
#
#
# FINDING:
# the breasts are heterogeneously dense, which may obscure small masses.   there are no significant masses, calcifications, or other findings
# GROUP: ('heterogeneously dense',)

# %%
#save processed data
df.to_json("data/reports_with_groups.json")

# %%
#print top 200 most frequent groups
counter = Counter(groups)
del counter[()]
counter.most_common()[:200]
# Out:
# [(('scattered fibroglandular densities',), 6174),
#  (('heterogeneously dense',), 4496),
#  (('biopsy clip', 'scattered fibroglandular densities'), 1216),
#  (('heterogeneously dense', 'biopsy clip'), 1054),
#  (('fatty',), 1030),
#  (('lumpectomy', 'scattered fibroglandular densities'), 886),
#  (('lumpectomy', 'heterogeneously dense'), 412),
#  (('benign calcification', 'heterogeneously dense'), 362),
#  (('extremely dense',), 328),
#  (('reduction', 'scattered fibroglandular densities'), 316),
#  (('benign calcification', 'scattered fibroglandular densities'), 286),
#  (('mass', 'scattered fibroglandular densities'), 278),
#  (('implant', 'scattered fibroglandular densities'), 257),
#  (('implant', 'heterogeneously dense'), 232),
#  (('mass', 'heterogeneously dense'), 215),
#  (('lumpectomy biopsy clip', 'scattered fibroglandular densities'), 210),
#  (('heterogeneously dense', 'lumpectomy biopsy clip'), 144),
#  (('fatty', 'biopsy clip'), 143),
#  (('heterogeneously dense', 'benign calcification', 'biopsy clip'), 122),
#  (('biopsy clip', 'extremely dense'), 116),
#  (('mass', 'heterogeneously dense', 'biopsy clip'), 106),
#  (('reduction', 'heterogeneously dense'), 93),
#  (('benign calcification',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   88),
#  (('mass', 'biopsy clip', 'scattered fibroglandular densities'), 87),
#  (('scattered fibroglandular densities', 'lumpectomy biopsy'), 82),
#  (('heterogeneously dense', 'obscured, oval, circumscribed, round'), 81),
#  (('asymmetry focal', 'scattered fibroglandular densities'), 71),
#  (('asymmetry', 'heterogeneously dense'), 69),
#  (('fatty', 'reduction'), 68),
#  (('fatty', 'lumpectomy'), 66),
#  (('heterogeneously dense', 'asymmetry focal'), 62),
#  (('lumpectomy reduction', 'scattered fibroglandular densities'), 60),
#  (('lumpectomy', 'benign calcification', 'scattered fibroglandular densities'),
#   57),
#  (('fatty', 'benign calcification'), 56),
#  (('asymmetry', 'scattered fibroglandular densities'), 54),
#  (('obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   50),
#  (('reduction biopsy clip', 'scattered fibroglandular densities'), 39),
#  (('heterogeneously dense', 'lumpectomy biopsy'), 38),
#  (('fatty', 'mass'), 37),
#  (('benign calcification', 'extremely dense'), 36),
#  (('heterogeneously dense',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip'),
#   32),
#  (('lymph node', 'scattered fibroglandular densities'), 29),
#  (('heterogeneously dense', 'architectural distortion'), 29),
#  (('lumpectomy', 'mass', 'scattered fibroglandular densities'), 28),
#  (('implant', 'extremely dense'), 25),
#  (('heterogeneously dense', 'lymph node'), 24),
#  (('lumpectomy', 'benign calcification', 'heterogeneously dense'), 23),
#  (('mass', 'benign calcification', 'heterogeneously dense'), 22),
#  (('implant', 'benign calcification', 'heterogeneously dense'), 22),
#  (('oval', 'scattered fibroglandular densities'), 20),
#  (('implant lumpectomy', 'scattered fibroglandular densities'), 20),
#  (('heterogeneously dense', 'grouped'), 19),
#  (('scattered fibroglandular densities', 'architectural distortion'), 19),
#  (('benign calcification', 'biopsy clip', 'extremely dense'), 19),
#  (('heterogeneously dense', 'implant biopsy clip'), 19),
#  (('heterogeneously dense', 'lumpectomy reduction'), 17),
#  (('scattered fibroglandular densities', 'lumpectomy reduction biopsy clip'),
#   17),
#  (('reduction', 'benign calcification', 'scattered fibroglandular densities'),
#   16),
#  (('mass', 'benign calcification', 'scattered fibroglandular densities'), 16),
#  (('heterogeneously dense', 'reduction biopsy clip'), 16),
#  (('reduction biopsy', 'scattered fibroglandular densities'), 16),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'heterogeneously dense'),
#   15),
#  (('heterogeneously dense', 'implant biopsy'), 15),
#  (('implant lumpectomy', 'heterogeneously dense'), 14),
#  (('lumpectomy', 'extremely dense'), 13),
#  (('fatty', 'lumpectomy biopsy clip'), 13),
#  (('obscured, oval, circumscribed, round',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   13),
#  (('benign calcification',
#    'lumpectomy biopsy clip',
#    'scattered fibroglandular densities'),
#   12),
#  (('implant biopsy clip', 'scattered fibroglandular densities'), 11),
#  (('benign calcification', 'lumpectomy biopsy clip', 'heterogeneously dense'),
#   11),
#  (('fatty', 'implant'), 10),
#  (('reduction', 'benign calcification', 'heterogeneously dense'), 10),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   10),
#  (('heterogeneously dense', 'benign calcification', 'mass', 'biopsy clip'),
#   10),
#  (('lumpectomy clip', 'scattered fibroglandular densities'), 9),
#  (('fatty', 'benign calcification', 'biopsy clip'), 8),
#  (('implant reduction', 'scattered fibroglandular densities'), 8),
#  (('mass', 'biopsy clip', 'extremely dense'), 8),
#  (('lumpectomy', 'heterogeneously dense', 'lymph node'), 8),
#  (('implant', 'heterogeneously dense', 'mass'), 8),
#  (('heterogeneously dense', 'oval'), 8),
#  (('grouped', 'scattered fibroglandular densities'), 8),
#  (('implant', 'benign calcification', 'scattered fibroglandular densities'),
#   7),
#  (('mass', 'extremely dense'), 7),
#  (('fatty', 'benign calcification', 'reduction'), 7),
#  (('implant reduction', 'heterogeneously dense'), 7),
#  (('benign calcification',
#    'reduction biopsy clip',
#    'scattered fibroglandular densities'),
#   7),
#  (('mass',
#    'benign calcification',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   7),
#  (('fatty', 'reduction biopsy'), 7),
#  (('reduction', 'extremely dense'), 7),
#  (('implant biopsy', 'scattered fibroglandular densities'), 7),
#  (('heterogeneously dense', 'reduction biopsy'), 7),
#  (('lymph node', 'biopsy clip', 'scattered fibroglandular densities'), 7),
#  (('lumpectomy', 'heterogeneously dense', 'mass'), 6),
#  (('reduction', 'benign calcification', 'extremely dense'), 6),
#  (('fatty', 'reduction biopsy clip'), 6),
#  (('lumpectomy', 'lymph node', 'scattered fibroglandular densities'), 6),
#  (('mass', 'lumpectomy biopsy clip', 'scattered fibroglandular densities'), 6),
#  (('lumpectomy biopsy clip', 'extremely dense'), 6),
#  (('implant', 'mass', 'scattered fibroglandular densities'), 6),
#  (('fatty', 'asymmetry focal'), 6),
#  (('vascular, benign calcification', 'scattered fibroglandular densities'), 5),
#  (('fatty', 'benign calcification', 'lumpectomy'), 5),
#  (('asymmetry', 'scattered fibroglandular densities', 'benign calcification'),
#   5),
#  (('fatty', 'lymph node'), 5),
#  (('benign calcification', 'heterogeneously dense', 'lumpectomy biopsy'), 5),
#  (('fatty', 'mass', 'reduction'), 5),
#  (('extremely dense', 'lumpectomy biopsy'), 5),
#  (('obscured, oval, circumscribed, round', 'extremely dense'), 5),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip',
#    'extremely dense'),
#   5),
#  (('grouped', 'heterogeneously dense', 'biopsy clip'), 5),
#  (('asymmetry', 'extremely dense'), 5),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'extremely dense'),
#   5),
#  (('benign calcification',
#    'lumpectomy reduction',
#    'scattered fibroglandular densities'),
#   5),
#  (('fatty', 'lumpectomy biopsy'), 5),
#  (('heterogeneously dense', 'asymmetry focal', 'biopsy clip'), 5),
#  (('vascular, benign calcification', 'heterogeneously dense'), 4),
#  (('fatty', 'benign calcification', 'mass'), 4),
#  (('implant', 'asymmetry', 'scattered fibroglandular densities'), 4),
#  (('heterogeneously dense', 'skin lesion'), 4),
#  (('fatty', 'mass', 'biopsy clip'), 4),
#  (('mass', 'lymph node', 'scattered fibroglandular densities'), 4),
#  (('fatty', 'asymmetry'), 4),
#  (('reduction', 'mass', 'scattered fibroglandular densities'), 4),
#  (('lumpectomy',
#    'heterogeneously dense',
#    'obscured, oval, circumscribed, round'),
#   4),
#  (('implant biopsy clip lumpectomy', 'heterogeneously dense'), 4),
#  (('benign calcification',
#    'scattered fibroglandular densities',
#    'lumpectomy biopsy'),
#   4),
#  (('scattered fibroglandular densities',
#    'asymmetry focal',
#    'architectural distortion'),
#   4),
#  (('heterogeneously dense', 'lumpectomy reduction biopsy clip'), 4),
#  (('fatty', 'obscured, oval, circumscribed, round'), 4),
#  (('implant', 'heterogeneously dense', 'obscured, oval, circumscribed, round'),
#   4),
#  (('lumpectomy', 'heterogeneously dense', 'skin thickening'), 4),
#  (('scattered fibroglandular densities', 'lymph node', 'lumpectomy biopsy'),
#   4),
#  (('implant',), 3),
#  (('heterogeneously dense', 'vascular'), 3),
#  (('scattered fibroglandular densities', 'lymph node', 'node'), 3),
#  (('fatty', 'lymph node', 'biopsy clip'), 3),
#  (('scattered fibroglandular densities', 'round'), 3),
#  (('benign calcification', 'lymph node', 'scattered fibroglandular densities'),
#   3),
#  (('extremely dense', 'architectural distortion'), 3),
#  (('benign calcification',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip',
#    'scattered fibroglandular densities'),
#   3),
#  (('mass', 'heterogeneously dense', 'lumpectomy biopsy clip'), 3),
#  (('lymph node',
#    'lumpectomy biopsy clip',
#    'scattered fibroglandular densities'),
#   3),
#  (('reduction biopsy clip', 'extremely dense'), 3),
#  (('lumpectomy', 'skin thickening', 'scattered fibroglandular densities'), 3),
#  (('heterogeneously dense', 'implant clip'), 3),
#  (('lumpectomy',
#    'trabecular thickening',
#    'scattered fibroglandular densities'),
#   3),
#  (('oval', 'lymph node', 'scattered fibroglandular densities'), 3),
#  (('lumpectomy', 'asymmetry', 'scattered fibroglandular densities'), 3),
#  (('mass', 'benign calcification', 'biopsy clip', 'extremely dense'), 3),
#  (('lumpectomy', 'asymmetry focal', 'scattered fibroglandular densities'), 3),
#  (('asymmetry focal', 'biopsy clip', 'scattered fibroglandular densities'), 3),
#  (('implant biopsy lumpectomy', 'scattered fibroglandular densities'), 3),
#  (('fatty', 'grouped', 'biopsy clip'), 3),
#  (('lumpectomy', 'heterogeneously dense', 'grouped'), 3),
#  (('benign calcification',
#    'post operative finding',
#    'scattered fibroglandular densities'),
#   2),
#  (('vascular', 'scattered fibroglandular densities'), 2),
#  (('oval, circumscribed, round', 'scattered fibroglandular densities'), 2),
#  (('grouped', 'extremely dense'), 2),
#  (('skin, benign calcification', 'scattered fibroglandular densities'), 2),
#  (('obscured, round', 'heterogeneously dense'), 2),
#  (('circumscribed', 'scattered fibroglandular densities'), 2),
#  (('mass', 'lumpectomy reduction', 'scattered fibroglandular densities'), 2),
#  (('mass', 'scattered fibroglandular densities', 'lumpectomy biopsy'), 2),
#  (('heterogeneously dense', 'round'), 2),
#  (('implant biopsy', 'extremely dense'), 2),
#  (('lumpectomy',
#    'dystrophic, benign calcification',
#    'scattered fibroglandular densities'),
#   2),
#  (('mass', 'heterogeneously dense', 'lymph node'), 2),
#  (('fatty', 'skin lesion'), 2),
#  (('implant biopsy clip', 'extremely dense'), 2),
#  (('obscured', 'scattered fibroglandular densities'), 2),
#  (('mass', 'implant biopsy clip', 'scattered fibroglandular densities'), 2),
#  (('reduction',
#    'obscured, oval, circumscribed, round',
#    'scattered fibroglandular densities'),
#   2),
#  (('asymmetry global', 'scattered fibroglandular densities'), 2),
#  (('heterogeneously dense', 'oval, circumscribed, equal density'), 2),
#  (('benign calcification', 'reduction biopsy clip', 'heterogeneously dense'),
#   2),
#  (('scattered fibroglandular densities', 'asymmetry developing'), 2),
#  (('heterogeneously dense', 'lymph node', 'lumpectomy biopsy'), 2),
#  (('heterogeneously dense', 'lymph node', 'biopsy clip'), 2),
#  (('mass', 'asymmetry focal', 'scattered fibroglandular densities'), 2),
#  (('mass',
#    'benign calcification',
#    'lumpectomy reduction',
#    'scattered fibroglandular densities'),
#   2),
#  (('asymmetry', 'biopsy clip', 'scattered fibroglandular densities'), 2),
#  (('obscured, oval', 'scattered fibroglandular densities'), 2),
#  (('lumpectomy',
#    'asymmetry',
#    'skin thickening',
#    'scattered fibroglandular densities'),
#   2),
#  (('implant', 'asymmetry', 'extremely dense'), 2),
#  (('benign calcification',
#    'scattered fibroglandular densities',
#    'lumpectomy reduction biopsy clip'),
#   2),
#  (('fatty', 'lumpectomy reduction'), 2),
#  (('mass', 'scattered fibroglandular densities', 'architectural distortion'),
#   2),
#  (('amorphous, grouped', 'scattered fibroglandular densities'), 2),
#  (('asymmetry',
#    'scattered fibroglandular densities',
#    'architectural distortion'),
#   2),
#  (('reduction clip', 'scattered fibroglandular densities'), 2),
#  (('grouped, benign calcification', 'heterogeneously dense', 'biopsy clip'),
#   2),
#  (('implant', 'benign calcification', 'extremely dense'), 2),
#  (('skin lesion', 'scattered fibroglandular densities'), 2),
#  (('skin thickening', 'scattered fibroglandular densities'), 2),
#  (('heterogeneously dense',
#    'benign calcification',
#    'obscured, oval, circumscribed, round',
#    'biopsy clip'),
#   2),
#  (('reduction', 'asymmetry focal', 'scattered fibroglandular densities'), 2),
#  (('linear', 'scattered fibroglandular densities'), 2),
#  (('heterogeneously dense', 'circumscribed, round'), 2),
#  (('lumpectomy', 'heterogeneously dense', 'architectural distortion'), 2)]
